# %%
import pandas as pd
from bs4 import BeautifulSoup
from unicodedata import normalize
import re
import requests

# %%
url = "https://en.wikipedia.org/wiki/Firearm_death_rates_in_the_United_States_by_state"
response = requests.get(url).text
soup = BeautifulSoup(response,'html.parser')
tables = soup.find_all('table')

# %%
i = 1

for table in tables:
    if i == 1:
        headers =  [header.text.strip() for header in table.find_all('th')]
        rows = []
        table_rows = table.find_all('tr')
        for row in table_rows:
            td = row.find_all('td')
            row = [row.text for row in td]
            rows.append(row)
    i += 1

# %%
headers.append('blank')

# %%
df_raw = pd.DataFrame(rows, columns=headers)

# %%
df = df_raw.copy()

# %%
df = df.drop(['blank'], axis=1)

# %%
df = df.drop(df.index[:1], axis=0)

# %%
df['State'] = df['State'].str.normalize('NFKD')

# %%
df['State'] = df['State'].str.replace(' *','')

# %%
j = 1

for table in tables:
    if j == 2:
        headers = [header.text.strip() for header in table.find_all('th')]
        rows = []
        table_rows = table.find_all('tr')
        for row in table_rows:
            td = row.find_all('td')
            cell = [cell.text for cell in td]
            rows.append(cell)
    j += 1

# %%
clean_headers = [re.sub('\n', '', x) for x in headers]

clean_headers = [re.sub('\(.*\)', '', x) for x in clean_headers]

clean_headers = [x for x in clean_headers if x != '']

clean_headers = [x.strip() for x in clean_headers]

# %%
clean_rows = [x for x in rows if x != []]

clean_rows = [[re.sub('\n|,', '', x) for x in group] for group in clean_rows]

df_2 = pd.DataFrame(clean_rows, columns=clean_headers)

# %%
df_2
# Out:
#                    State Population Population density Murders Gunmurders  \
# 0                Alabama    4779736              94.65     199        135
# 1                 Alaska     710231              1.264      31         19
# 2                Arizona    6392017              57.05     326        232
# 3               Arkansas    2915918              56.43     130         93
# 4             California   37253956              244.2    1811       1257
# 5               Colorado    5029196              49.33     117         65
# 6            Connecticut    3574097              741.4     131         97
# 7               Delaware     897934              470.7      48         38
# 8   District of Columbia     601723              10298     131         99
# 9                Florida   19687653              360.2     987        669
# 10               Georgia    9920000                165     527        376
# 11                Hawaii    1360301              216.8      24          7
# 12                 Idaho    1567582               19.5      21         12
# 13              Illinois   12830632              231.9     706        364
# 14               Indiana    6483802              182.5     198        142
# 15                  Iowa    3046355              54.81      38         21
# 16                Kansas    2853118              35.09     100         63
# 17              Kentucky    4339367              110.0     180        116
# 18             Louisiana    4533372              105.0     437        351
# 19                 Maine    1328361              43.04      24         11
# 20              Maryland    5773552              606.2     424        293
# 21         Massachusetts    6547629              852.1     209        118
# 22              Michigan    9883640              174.8     558        413
# 23             Minnesota    5303925              67.14      91         53
# 24           Mississippi    2967297              63.50     165        120
# 25              Missouri    5988927              87.26     419        321
# 26               Montana     989415              6.858      21         12
# 27              Nebraska    1826341              23.97      51         32
# 28                Nevada    2700551              24.80     158         84
# 29         New Hampshire    1316470              147.0      13          5
# 30            New Jersey    8791894               1189     363        246
# 31            New Mexico    2059179              17.16     118         67
# 32              New York   19378102              415.3     860        517
# 33        North Carolina    9535483              200.6     445        286
# 34          North Dakota     672591              9.916       9          4
# 35                  Ohio   11536504              282.5     460        310
# 36              Oklahoma    3751351              55.22     188        111
# 37                Oregon    3831074              40.33      78         36
# 38          Pennsylvania   12702379              285.3     646        457
# 39          Rhode Island    1052567               1006      29         16
# 40        South Carolina    4625364              157.1     280        207
# 41          South Dakota     814180              10.86      14          8
# 42             Tennessee    6346105              156.6     356        219
# 43                 Texas   25145561              98.07    1246        805
# 44                  Utah    2763885              34.30      52         22
# 45               Vermont     625741              67.73       7          2
# 46              Virginia    8001024              207.3     369        250
# 47            Washington    6724540              102.6     151         93
# 48         West Virginia    1852994              77.06      55         27
# 49             Wisconsin    5686986              105.2     151         97
# 50               Wyoming     563626              5.851       8          5
#
#    Estimated Gunownership Murders Gunmurders
# 0                   48.9%     4.2        2.8
# 1                   61.7%     4.4        2.7
# 2                   32.3%     4.5        3.6
# 3                   57.9%     4.5        3.2
# 4                   20.1%     4.9        3.4
# 5                   34.3%     2.3        1.3
# 6                   16.6%     3.7        2.7
# 7                    5.2%     5.3        4.2
# 8                   25.9%    21.8       16.5
# 9                   32.5%     5.0        3.4
# 10                  31.6%     5.3        3.8
# 11                  45.1%     1.8        0.5
# 12                  56.9%     1.3        0.8
# 13                  26.2%     5.5        2.8
# 14                  33.8%     3.1        2.2
# 15                  33.8%     1.2        0.7
# 16                  32.2%     3.5        2.2
# 17                  42.4%     4.5        2.7
# 18                  44.5%     9.6        7.7
# 19                  22.6%     1.8        0.8
# 20                  20.7%     7.3        5.1
# 21                  22.6%     3.2        1.8
# 22                  28.8%     5.6        4.2
# 23                  36.7%     1.7        1.0
# 24                  42.8%     5.6        4.0
# 25                  27.1%     7.0        5.4
# 26                  52.3%     2.1        1.2
# 27                  19.8%     2.8        1.8
# 28                  37.5%     5.9        3.1
# 29                  14.4%     1.0        0.4
# 30                  11.3%     4.1        2.8
# 31                  49.9%     5.7        3.3
# 32                  10.3%     4.4        2.7
# 33                  28.7%     4.7        3.0
# 34                  47.9%     1.3        0.6
# 35                  19.6%     4.0        2.7
# 36                  31.2%     5.0        3.0
# 37                  26.6%     2.0        0.9
# 38                  27.1%     5.1        3.6
# 39                   5.8%     2.8        1.5
# 40                  44.4%     6.1        4.5
# 41                  35.0%     1.7        1.0
# 42                  39.4%     5.6        3.5
# 43                  35.7%     5.0        3.2
# 44                  31.9%     1.9        0.8
# 45                  28.8%     1.1        0.3
# 46                  29.3%     4.6        3.1
# 47                  27.7%     2.2        1.4
# 48                  54.2%     3.0        1.5
# 49                  34.7%     2.7        1.7
# 50                  53.8%     1.4        0.9
